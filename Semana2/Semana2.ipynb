# %% [markdown]
# # Ejercicios Semana 2 - Métodos Computacionales 2
# Daniel Dorado & Juan Pablo Salas
# ## Presentación de funciones

# %%
import numpy as np
import matplotlib.pyplot as plt
from celluloid import Camera
import scipy as sp
from scipy import integrate

# %% [markdown]
# Consideremos la serie $$ f(t) = 2 \sum_{n=1}^{\infty} \frac{(-1)^{n-1}}{n} \sin(n t).$$

# %%
def f (t, n):
    return 2*(-1)**(n-1)*np.sin(n*t)/n

# %%
L = np.pi
x = np.linspace(-3*L, 3*L, 1000)
n = 1
nt = 50
F = 0
fig = plt.figure(figsize=(6,6))
camera = Camera(fig)

while n < nt:
    F += f(x,n)
    plt.plot(x,F,c='k')
    camera.snap()
    n += 1

# %%
animation = camera.animate()
animation.save('Fourier.gif')
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [markdown]
# ## Función $\zeta(s)$ de Riemann

# %% [markdown]
# ## Derivada espectral
